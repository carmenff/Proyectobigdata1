# %% [markdown]
# Nuestro objetivo trata de detectar anomalias en los daños de una batidora

# %%
#Importamos las librerias necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargamos los datos
df = pd.read_csv("DATOS_COMPLETOS.CSV", delimiter= ';', parse_dates=['DateObserved'])

# %%
#Observamos los 10 primeros datos del dataset
df.head(10)
# Out:
#        Id   Machine              DateStr        DateObserved     H     V    C
# 0  921880  Batidora  01/09/2018 13:39:16 2018-09-01 13:39:16  0.18  0.14  0.1
# 1  921881  Batidora  01/09/2018 13:39:46 2018-09-01 13:39:46  0.17  0.15  0.1
# 2  921882  Batidora  01/09/2018 13:40:15 2018-09-01 13:40:15  0.17  0.17  0.1
# 3  921883  Batidora  01/09/2018 13:42:56 2018-09-01 13:42:56  0.17  0.16  0.1
# 4  921884  Batidora  01/09/2018 13:43:26 2018-09-01 13:43:26  0.17  0.19  0.1
# 5  921885  Batidora  01/09/2018 13:43:56 2018-09-01 13:43:56  0.20  0.18  0.1
# 6  921886  Batidora  01/09/2018 13:44:26 2018-09-01 13:44:26  0.18  0.17  0.1
# 7  921887  Batidora  01/09/2018 13:44:55 2018-09-01 13:44:55  0.18  0.17  0.1
# 8  921888  Batidora  01/09/2018 13:45:25 2018-09-01 13:45:25  0.22  0.16  0.1
# 9  921889  Batidora  01/09/2018 13:45:55 2018-09-01 13:45:55  0.18  0.16  0.1

# %%
#Miramos si el datatype de cada columna es el que necesitamos. Si no transformamos.
df.info()
#Nos aseguramos de que la fecha este bien puesta
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700626 entries, 0 to 700625
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Id            700626 non-null  int64
#  1   Machine       700626 non-null  object
#  2   DateStr       700626 non-null  object
#  3   DateObserved  700626 non-null  datetime64[ns]
#  4   H             700598 non-null  float64
#  5   V             700626 non-null  float64
#  6   C             700619 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 37.4+ MB

# %%
#Examinamos la columna Machine
df.Machine.value_counts()
# Out:
# Batidora    700626
# Name: Machine, dtype: int64

# %% [markdown]
# Todos los valores de la columna machine son batidora asi que podemos eliminar la columna

# %% [markdown]
# Eliminamos las columnas 'Id', 'DateStr', 'Machine', ordenamos por fecha y le establecemos un límite.

# %%
#Creamos dataframe con las columnas que nos interesan:
# batidora = df.loc[df['Machine']== 'Batidora']
batidora = df
cols = ['Id', 'DateStr', 'Machine']
batidora.drop(cols, axis=1, inplace=True)
batidora = batidora.sort_values('DateObserved')
batidora = batidora.set_index('DateObserved')
batidora
# Out:
#                         H     V    C
# DateObserved
# 2018-09-01 13:39:16  0.18  0.14  0.1
# 2018-09-01 13:39:46  0.17  0.15  0.1
# 2018-09-01 13:40:15  0.17  0.17  0.1
# 2018-09-01 13:42:56  0.17  0.16  0.1
# 2018-09-01 13:43:26  0.17  0.19  0.1
# ...                   ...   ...  ...
# 2019-04-30 12:28:48  0.22  0.21  0.1
# 2019-04-30 12:29:16  0.25  0.23  0.1
# 2019-04-30 12:29:45  0.24  0.22  0.1
# 2019-04-30 12:30:13  0.23  0.23  0.1
# 2019-04-30 12:30:43  0.25  0.25  0.1
#
# [700626 rows x 3 columns]

# %% [markdown]
# Revisamos los valores nulos por si podmeos despreciarlos o rellenar los valores nulos co la media, con media ponderada...

# %%
#Miramos cuantos nans hay:
batidora.isnull().sum()
# Out:
# H    28
# V     0
# C     7
# dtype: int64

# %% [markdown]
# Como son ta pocos respecto al total de valores y voy a tomar medias de ventanas temporales, podemos eliminarlos sin problema

# %%
batidora.dropna(axis=0, inplace=True)
batidora.isnull().sum()
# Out:
# H    0
# V    0
# C    0
# dtype: int64

# %% [markdown]
# ## 4.Distribución de los datos

# %% [markdown]
# Primero respresento la distribución de los datos de las variables

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20,6))
dfsub=df
ax[0].hist(dfsub['H'],bins=30)
ax[1].hist(dfsub['V'],bins=30)
ax[2].hist(dfsub['C'],bins=30)
ax[0]. title.set_text ('Vibracion_Horizontal')
ax[1].title.set_text("Vibracion_Vertical")
ax[2].title.set_text ('Corriente')
plt.show ()

# %% [markdown]
# A primera vista vemos que en los 3 histogramas tenemos una gran cantidad de datos cercanos al 0, por lo que podemos decir que estan bien distribuidos. Pasamos a ver como estan distribuidos los percentiles

# %% [markdown]
# Visualizamos la ditribución de los datos percentiles

# %%
df.describe(percentiles=(.1, .25, .5, .75, .9, .95, 0.99))
# Out:
#                    H              V              C
# count  700598.000000  700626.000000  700619.000000
# mean        0.226446       0.243882       0.594269
# std         0.191817       0.165516       2.673160
# min         0.110000       0.090000       0.080000
# 10%         0.160000       0.160000       0.090000
# 25%         0.180000       0.180000       0.090000
# 50%         0.200000       0.220000       0.100000
# 75%         0.230000       0.260000       0.100000
# 90%         0.260000       0.310000       0.100000
# 95%         0.280000       0.360000       0.110000
# 99%         1.230000       1.220000      15.620000
# max         5.240000      12.570000      24.050000

# %% [markdown]
# Examinamos gráficamente los datos. Primero veo como se comportan globalmente:

# %%
df = batidora
x=df.index
y=df.C

plt.figure(figsize=(20,7))
plt.plot(x,y)
plt.show()

# %%
batidora.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# Vemos datos que estan separados como por franjas

# %%
fig, ax=plt.subplots(figsize=(20,7))
df=batidora
x=df.index

ax.plot(x,df['H'], label='H')
ax.plot(x,df['V'], label='V')
ax.legend()
plt.show()

# %% [markdown]
# Al comparar vemos que comparten las franjas, por lo que podemos deducir que la máquina esta parada durante esas franjas de tiempo.

# %%
#Ploteo datos 1 hora:
df7=df.loc['2018-11-30':'2018-11-30 06:00']

fig, ax = plt.subplots(figsize=(20,7))
x= df7.index
ax.plot(x,df7['H'])
ax.plot(x,df7['V'])
ax.plot(x,df7['C'])
plt.show()

# %% [markdown]
# Observamos que hay una mayoría de datos muy próximos a 0. En este caso puede que sea el tiempo en el que la máquina está apagada. Examino la distribución de datos de la variable Corriente (C).

# %%
#Miramos los percentiles de sus valores para ver en que horas la máquina esta funcionando:
df.C.describe(percentiles=(.1, .25, .5, .75, .9, .95, 0.99))
# Out:
# count    700591.000000
# mean          0.594289
# std           2.673212
# min           0.080000
# 10%           0.090000
# 25%           0.090000
# 50%           0.100000
# 75%           0.100000
# 90%           0.100000
# 95%           0.110000
# 99%          15.620000
# max          24.050000
# Name: C, dtype: float64

# %%
#Observamos la distribucion de su histograma:

# %%
plt.hist(df.C)#,bins=50)
plt.xticks(np.arange(25, step=2))
plt.show()

# %%
plt.hist(df[df.C<.5]['C'])
plt.show()

# %%
plt.hist(df[df.C<.2]['C'])
plt.show()

# %%
df.C.value_counts()
# Out:
# 0.10     461652
# 0.09     183551
# 0.11      29516
# 14.28       627
# 14.30       615
#           ...
# 3.67          1
# 18.84         1
# 3.59          1
# 7.06          1
# 8.77          1
# Name: C, Length: 1556, dtype: int64

# %%
perc=df.C.value_counts().max()/len(df)*100
print("Un {:.2f}% de los valores de C son 0.1".format(perc))
# Out:
# Un 65.89% de los valores de C son 0.1

# %% [markdown]
# Parece que durante gran parte del tiempo la corriente oscila entre 0.08 y 0.11, habiendo un gran salto entre salto entre ese rango y el resto de valores. Dicho rango debe corresponderse con el tiempo en que la máquina está apagada, así que podemos deshacernos de esos datos porque no nos son relevantes

# %%
df=df[df.C>0.11]
df
# Out:
#                         H     V      C
# DateObserved
# 2018-09-06 10:21:25  0.16  0.15   0.12
# 2018-09-06 10:37:01  5.08  2.18  16.84
# 2018-09-06 10:37:31  1.93  1.90  16.17
# 2018-09-06 10:38:01  1.94  1.83  16.18
# 2018-09-06 10:38:30  1.95  1.77  16.21
# ...                   ...   ...    ...
# 2019-04-27 11:18:33  0.79  0.85  14.70
# 2019-04-27 11:19:03  0.80  0.90  14.64
# 2019-04-27 11:19:31  0.55  0.77  14.48
# 2019-04-27 11:20:00  0.52  0.78  14.46
# 2019-04-27 11:20:29  0.54  0.73  14.54
#
# [25521 rows x 3 columns]

# %%
x=range(len(df))
y=df.C

plt.figure(figsize=(20,7))
plt.plot(x,y)
plt.show()

# %%
#Ploteamos las 3 variables en el mismo gráfico
dfsub=df.loc['2018-9-6 10':'2018-9-7 02']

fig,ax = plt.subplots(figsize=(20,7))
x=dfsub.index
ax.plot(x,dfsub['H'])
ax.plot(x,dfsub['V'])
ax.plot(x,dfsub['C'])
plt.show()

# %% [markdown]
# Podemos intuir que los datos estan correlacionados con el tiempo, por lo que vamos a comprobarlo

# %%
#Ploteamos solo H
plt.figure(figsize=(20,7))
plt.plot(x,dfsub['H'])
plt.show()

# %% [markdown]
# Estudiamos la correlación entre las variables

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Visualmente vemos cómo H y C no muestran una relación apreciable, pero V sí muestra cierta relación lineal tanto con H como con C.
#
# Con .corr() podemos ver la correlación entre las variables. En qué grado están relacionadas linealmente:

# %%
sns.heatmap(df.corr(), annot=True, cmap="Blues")

# %% [markdown]
# Usando el método OLS también podemos estudiar la relación entre las variables. Si por ejemplo nos fijamos en el p-valor(P>[t]), sabemos que si es muy cercano a 0 hay una alta probabilidad de que ambas variables estén relacionadas

# %%
import statsmodels.api as sm

slr_model = sm.OLS(df['C'], df[['H', 'V']])
slr_reg = slr_model.fit()

slr_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      C   R-squared (uncentered):                   0.782
# Model:                            OLS   Adj. R-squared (uncentered):              0.782
# Method:                 Least Squares   F-statistic:                          4.584e+04
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        16:58:48   Log-Likelihood:                         -84721.
# No. Observations:               25521   AIC:                                  1.694e+05
# Df Residuals:                   25519   BIC:                                  1.695e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
slr_model = sm.OLS(df['H'], df['V'])
slr_reg = slr_model.fit()

slr_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                      H   R-squared (uncentered):                   0.895
# Model:                            OLS   Adj. R-squared (uncentered):              0.895
# Method:                 Least Squares   F-statistic:                          2.187e+05
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):                        0.00
# Time:                        17:01:13   Log-Likelihood:                         -10927.
# No. Observations:               25521   AIC:                                  2.186e+04
# Df Residuals:                   25520   BIC:                                  2.186e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Vemos que en todos los casos el p-valor es 0 o cercano a 0. Si el p-valor es muy cercano a 0 (<0.05) hay alta probabilidad de que la hipótesis nula sea falsa, por ende, están relacionadas entre sí.

# %%
X=df.values
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.00587084, 0.00160772, 0.        ],
#        [0.96868885, 0.164791  , 0.69870455],
#        [0.35225049, 0.14228296, 0.67070623],
#        ...,
#        [0.08219178, 0.05144695, 0.60008358],
#        [0.07632094, 0.0522508 , 0.59924781],
#        [0.08023483, 0.04823151, 0.60259089]])

# %%
X_scaled.shape
# Out:
# (25521, 3)

# %%
dfscaled=pd.DataFrame(X_scaled, columns=['H', 'V', 'C'])
dfscaled
# Out:
#               H         V         C
# 0      0.005871  0.001608  0.000000
# 1      0.968689  0.164791  0.698705
# 2      0.352250  0.142283  0.670706
# 3      0.354207  0.136656  0.671124
# 4      0.356164  0.131833  0.672378
# ...         ...       ...       ...
# 25516  0.129159  0.057878  0.609277
# 25517  0.131115  0.061897  0.606770
# 25518  0.082192  0.051447  0.600084
# 25519  0.076321  0.052251  0.599248
# 25520  0.080235  0.048232  0.602591
#
# [25521 rows x 3 columns]

# %%
#dfsub=df.loc['2018-9-6 10': '2018-9-7 02]
dfsub=df.iloc[:393]

fig, ax = plt.subplots(figsize=(20,7))
x=range(len(dfsub))
ax.plot(x, dfsub['H'])
ax.plot(x, dfsub['V'])
ax.plot(x, dfsub['C'])
plt.show()

# %% [markdown]
# Se observa que si que estan relacionados

# %%
#Escalamos la variables y las ploteamos en la misma gráfica para apreciarlas mejor visualmente:
dfsub=dfscaled.loc[:393]

fig, ax = plt.subplots(figsize=(20,7))
x=dfsub.index
ax.plot(x, dfsub['H'])
ax.plot(x, dfsub['V'])
ax.plot(x, dfsub['C'])
plt.show()

# %%
#Graficación en pila

dfsub=dfscaled.loc[:100]
x=dfsub.index

fig, ax= plt.subplots(figsize=(20,7))

plt.plot([], [], color='magenta', label = 'H')
plt.plot([], [], color='blue', label = 'V')
plt.plot([], [], color='red', label = 'C')

plt.stackplot(x, dfsub['H'], dfsub['V'], dfsub['C'], colors = ['magenta', 'blue', 'red'])
plt.legend(loc=2)
plt.title('Batidora')
plt.xlabel('Tiempo')
plt.ylabel('Valor')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(20,6))
dfsub=df.iloc[:100]
ax[0].hist(dfsub['H'],bins=30)
ax[1].hist(dfsub['V'],bins=30)
ax[2].hist(dfsub['C'],bins=30)

ax[0].title.set_text('H')
ax[1].title.set_text('V')
ax[2].title.set_text('C')
plt. show()

# %% [markdown]
# Como conclusiones sacamos que estan altamente correlacionados la vibración horizontal y vertical y que es una máquina discontinua con patrones.
